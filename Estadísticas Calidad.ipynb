# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
calidad = pd.read_excel('analisis-requerimientos.xlsx')
calidad.count()
# Out:
# nombre                  48
# tiene_id                48
# calidad_descripcion     48
# nombre_descriptivo      48
# indica_actores          48
# tiene_info_version      48
# calidad_trazabilidad    48
# indica_importancia      48
# indica_estabilidad      48
# tiene_comentarios       48
# tiene_cu                48
# tiene_hu                48
# fue_implementado        48
# ajuste                  48
# dtype: int64

# %%
#color_list = ['ymrg']
ax = calidad[['nombre', 'tiene_id']].groupby('tiene_id').count().plot.pie(
    title="Requerimientos según tiene o no identificador único", 
    subplots=True,
    legend=False,
    fontsize=14,
    figsize=(7,7)
    # color=color_list
)
plt.show()
#plt.savefig('requermientos-por-id.png')

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'calidad_descripcion']].groupby('calidad_descripcion').count().plot.bar(
    title="Requerimientos según calidad en la descripción (Alta|Media|Baja)", 
    legend=False,
    fontsize=14,
    figsize=(7,7),
    color=color_list    
)

ax.set_xlabel('Calidad en la descripción', fontsize=12)
ax.set_ylabel('Cantidad de requerimientos', fontsize=12)
plt.show()
#plt.savefig('requermientos-por-calidad-descripcion.png')

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'nombre_descriptivo']].groupby('nombre_descriptivo').count().plot.barh(
    title="Requerimientos según nombre descriptivo", 
    legend=False,
    fontsize=14,
    figsize=(7,7),
    color=color_list    
)

ax.set_xlabel('Cantidad de requerimientos', fontsize=12)
ax.set_ylabel('Calidad en la descripción', fontsize=12)
plt.show()
#plt.savefig('requermientos-por-nombre-descriptivo.png')

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'indica_actores']].groupby('indica_actores').count().plot.bar(
    title="Requerimientos según indica actores", 
    legend=False,
    fontsize=14,
    figsize=(6,6),
    color=color_list    
)

ax.set_xlabel('Indica o no actores', fontsize=12)
ax.set_ylabel('Cantidad de requerimientos', fontsize=12)
plt.show()
#plt.savefig('requermientos-segun-indica-actores.png')

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'tiene_info_version']].groupby('tiene_info_version').count().plot.pie(
    title="Requerimientos según indica versión",
    subplots=True,
    legend=False,
    fontsize=14,
    figsize=(7,7)    
)

plt.show()
#plt.savefig('requermientos-según-indica-version.png)

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'calidad_trazabilidad']].groupby('calidad_trazabilidad').count().plot.bar(
    title="Requerimientos según calidad en la trazabilidad", 
    legend=False,
    fontsize=14,
    figsize=(6,6),
    color=color_list    
)

ax.set_xlabel('Calidad en la trazabilidad', fontsize=12)
ax.set_ylabel('Cantidad de requerimientos', fontsize=12)
plt.show()
#plt.savefig('requermientos-según-calidad-trazabilidad.png)

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'indica_importancia']].groupby('indica_importancia').count().plot.pie(
    title="Requerimientos según indica importancia",
    subplots=True,
    legend=False,
    fontsize=14,
    figsize=(7,7)    
)

plt.show()
#plt.savefig('requermientos-según-indica-importancia.png)

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'tiene_comentarios']].groupby('tiene_comentarios').count().plot.pie(
    title="Requerimientos según tiene comentarios",
    subplots=True,
    legend=False,
    fontsize=14,
    figsize=(7,7)    
)

plt.show()
#plt.savefig('requermientos-según-tiene-comentarios.png)

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'tiene_cu']].groupby('tiene_cu').count().plot.barh(
    title="Requerimientos según tiene caso de uso", 
    legend=False,
    fontsize=14,
    figsize=(7,7),
    color=color_list    
)

ax.set_xlabel('Cantidad de requerimientos', fontsize=12)
ax.set_ylabel('Tiene Caso de uso', fontsize=12)
plt.show()
#plt.savefig('requermientos-segun-tiene-cu.png')

# %%
color_list = ['rg']
ax = calidad[['nombre', 'tiene_hu']].groupby('tiene_hu').count().plot.bar(
    title="Requerimientos según tiene Historia de Usuario", 
    legend=False,
    fontsize=14,
    figsize=(6,6),
    color=color_list    
)

ax.set_xlabel('Tiene Historia de Usuario', fontsize=12)
ax.set_ylabel('Cantidad de requerimientos', fontsize=12)
plt.show()
#plt.savefig('requermientos-según-tiene-hu.png)

# %%
color_list = ['gyr']
ax = calidad[['nombre', 'fue_implementado']].groupby('fue_implementado').count().plot.pie(
    title="Requerimientos según fue implementado",
    subplots=True,
    legend=False,
    fontsize=14,
    figsize=(7,7)    
)

plt.show()
#plt.savefig('requermientos-según-fue-implementado.png)

# %% [markdown]
# ## Ejemplos para pensar posibles gráficas

# %% [markdown]
# Podríamos buscar algunos de los requerimientos más importantes y hacer algo así ? Tiene sentido ? Dice algo ?

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %% [markdown]
# Y ésta ? Por ejemplo en x los requerimientos en y la cantidad y los colorsitos son algunos de los atributos con valores verdadero o falso (Ej: fue implementado, tiene HU, y tiene comentarios)

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]

y = np.vstack([y1, y2, y3])

labels = ["Fibonacci ", "Evens", "Odds"]

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc='upper left')
plt.show()

fig, ax = plt.subplots()
ax.stackplot(x, y)
plt.show()

# %% [markdown]
# La matoría de las gráficas básicas no son muy significativas. Lo que podríamos pensar es en algunas consultas más complejas, que involucren medias o varios atributos y sacar dos o trés gráficas un toque más piolas.

# %% [markdown]
# # Hacer el ajuste
# # ver dockerfile y compose
# # probar selenium
# # ver formula para correctitud
